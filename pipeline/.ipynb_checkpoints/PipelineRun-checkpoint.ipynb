# %% [markdown]
# Assumption:
# 1. data gets updated every day
# 2. Today is 6/7/19 (?)

# %%
# Read following package
import pandas as pd
import seaborn as sns
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# Funcitons
from PreEval import PolicyDayBefore, ConfirmedCases
from MobilityPredict import model_predict

from pandas import DataFrame
from IPython.display import HTML

# %%
# Read data (policy+mobility combined)
data = pd.read_csv('/Users/Jenny/Desktop/COVID19/cleaned/policy_mobiliy.csv')

# %%
# Only have following policies available
policy = ['STEMERG', 'CLSCHOOL', 'CLDAYCR',
       'FM_ALL', 'FM_EMP', 'CLNURSHM', 'EVICINTN', 'EVICENF',
       'STAYHOME', 'END_STHM', 'CLBSNS', 'END_BSNS', 'CLREST', 'ENDREST',
       'CLGYM', 'ENDGYM', 'CLMOVIE', 'END_MOV']

# %% [markdown]
# # Pre-evaluation

# %% [markdown]
# ### What policies are still active?

# %%
myList = PolicyDayBefore(data, state = 'IL', policy_lst = policy)
HTML(DataFrame(myList).to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>policy</th>
#       <th>description</th>
#       <th>status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>STEMERG</td>
#       <td>State of emergency</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>CLSCHOOL</td>
#       <td>Date closed K-12 schools</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>CLDAYCR</td>
#       <td>Closed day cares</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>FM_ALL</td>
#       <td>Mandate face mask use by all individuals in public spaces</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>FM_EMP</td>
#       <td>Mandate face mask use by employees in public-facing businesses</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>CLNURSHM</td>
#       <td>Date banned visitors to nursing homes</td>
#       <td>inactive</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>EVICINTN</td>
#       <td>Stop Initiation of Evictions overall or due to COVID related issues</td>
#       <td>inactive</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>EVICENF</td>
#       <td>Stop enforcement of evictions overall or due to COVID related issues</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>STAYHOME</td>
#       <td>Stay at home/ shelter in place</td>
#       <td>inactive</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>END_STHM</td>
#       <td>End/relax stay at home/shelter in place</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>CLBSNS</td>
#       <td>Closed non-essential businesses</td>
#       <td>inactive</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>END_BSNS</td>
#       <td>Began to reopen businesses</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>CLREST</td>
#       <td>Closed restaurants except take out</td>
#       <td>inactive</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>ENDREST</td>
#       <td>Reopen restaurants</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>CLGYM</td>
#       <td>Closed gyms</td>
#       <td>inactive</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>ENDGYM</td>
#       <td>Reopened gyms</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>CLMOVIE</td>
#       <td>Closed movie theaters</td>
#       <td>active</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>END_MOV</td>
#       <td>Reopened movie theaters</td>
#       <td>inactive</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### How many confirmed cases we have so far? What is the trending of daily new cases?

# %%
cases = ConfirmedCases(data, 'IL')
cases.show_total()
cases.show_daily_new()

# %%
# You can also put start and end date of the time period you want to look at. Format has to be 'yyyy-mm-dd'
cases = ConfirmedCases(data, 'IL', start='2020-06-01')
cases.show_total()
cases.show_daily_new()

# %% [markdown]
# # New Policies

# %% [markdown]
# ### What policies are we going to implement from tomorrow?

# %% [markdown]
# #### Put your policies in the corresponding bracket. For example: inactive=['policy1', 'policy2']

# %%
print('Stop following policies:')  # put the policy code in ['policy1', 'policy2'...]
inactive = ['CLDAYCR', 'CLMOVIE']
print(inactive)

print('\n')

print('Start following:')
active = ['END_MOV']
print(active)
# Out:
# Stop following policies:
# ['CLDAYCR', 'CLMOVIE']
#
#
# Start following:
# ['END_MOV']

# %% [markdown]
# # Predict Mobility

# %% [markdown]
# ### Based on the policies we choose to change, what is the predicted mobility of the next 7 days? How does it compare to the predicted mobility if we don't change policies?

# %%
mobility_pred, mobility_pred_unchanged = model_predict(data, policy, 'IL', 'retail_and_recreation', active, inactive)
# Out:
# /Users/Jenny/Desktop/COVID19/pipeline/MobilityPredict.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['a_date'] = pd.to_datetime(df['a_date'])
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#         date  predicted mobility with changed policy  \
# 0 2020-06-08                              -18.325679
# 1 2020-06-09                              -18.229783
# 2 2020-06-10                              -18.389918
# 3 2020-06-11                              -18.637767
# 4 2020-06-12                              -18.359925
# 5 2020-06-13                              -19.693419
# 6 2020-06-14                              -21.700273
#
#    predicted mobility with old policy remained
# 0                                   -23.278792
# 1                                   -22.767974
# 2                                   -23.214843
# 3                                   -23.198718
# 4                                   -23.243764
# 5                                   -24.295122
# 6                                   -26.725611

# %% [markdown]
# # Predicted Confirmed Cases
# #### Please note:
# This block acts as a placeholder. User should replace this block with a better predictive model that uses mobility as some of the predictors and confirmed cases as target variable. The model being used here is a badly fit model using mobility as the only predictor.

# %%
import pickle
with open('/Users/Jenny/Desktop/COVID19/models/casesModel.pkl', 'rb') as f:
    caseModel = pickle.load(f)

# %%
cases_pred = np.exp(caseModel.predict(mobility_pred.reshape(-1, 1)))
cases_pred_unchanged = np.exp(caseModel.predict(mobility_pred_unchanged.reshape(-1, 1)))

# %%
df = data[data.a_state=='IL']
df['daily_new_cases'] = df['confirmed_cases_state'].diff()
df.a_date = pd.to_datetime(df.a_date)
future_date = [pd.to_datetime(data['a_date']).iloc[-1] + datetime.timedelta(days=i) for i in range(1, 8)]

plt.subplots(figsize = (14,7))
ax = sns.lineplot(future_date, cases_pred, label='future if change policy indicated above')
ax.lines[0].set_linestyle("--")
sns.lineplot(df.a_date, df.daily_new_cases, label='past', color='orange')
sns.lineplot(future_date, cases_pred_unchanged, label='future if remain same policy', color='orange')
ax.lines[2].set_linestyle("--")
plt.legend()
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
